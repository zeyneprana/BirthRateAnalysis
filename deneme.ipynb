# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("dataset.csv")
df.head()

# %%
sns.heatmap(df.select_dtypes(include='number').corr(), annot=True) #sadece sayısal değerleri al  Kategorik verilerini sayıya çevir, heatmap'İn orijinalini kullan!
# Out:
# <Axes: >

# %%
sns.histplot(df['Average Age of Mother (years)']) #Bu değerler nasıl dağılıyor? - Average Age of Mother
# Out:
# <Axes: xlabel='Average Age of Mother (years)', ylabel='Count'>

# %%
sns.scatterplot(data = df , x ='Average Age of Mother (years)' , y ='Average Birth Weight (g)')
# Out:
# <Axes: xlabel='Average Age of Mother (years)', ylabel='Average Birth Weight (g)'>

# %%
sns.scatterplot(data = df , x ='Education Level Code' , y ='Average Birth Weight (g)' , hue = 'BirthRateClass')
#hue parametresine genelde target feature verilir.
# Out:
# <Axes: xlabel='Education Level Code', ylabel='Average Birth Weight (g)'>

# %% [markdown]
# Boyut İndirgeme Teknikleri - PCA

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2,random_state=53)

# %%
x = df.drop('BirthRateClass',axis=1) #features
y = df['BirthRateClass']                       #target

# %%
y
